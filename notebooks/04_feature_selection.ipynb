# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import RandomForestClassifier

pd.set_option("display.max_columns", None)

df = pd.read_csv("../data/processed/diabetes_cleaned.csv")

# %%
print(df.shape)

df.head()
# Out:
# (101766, 45)
#               race  gender      age  admission_type_id  \
# 0        Caucasian  Female   [0-10)                  6
# 1        Caucasian  Female  [10-20)                  1
# 2  AfricanAmerican  Female  [20-30)                  1
# 3        Caucasian    Male  [30-40)                  1
# 4        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1    Unknown
# 1                         1                    7                 3    Unknown
# 2                         1                    7                 2    Unknown
# 3                         1                    7                 2    Unknown
# 4                         1                    7                 1    Unknown
#
#           medical_specialty  num_lab_procedures  num_procedures  \
# 0  Pediatrics-Endocrinology                  41               0
# 1                   Unknown                  59               0
# 2                   Unknown                  11               5
# 3                   Unknown                  44               1
# 4                   Unknown                  51               0
#
#    num_medications  number_outpatient  number_emergency  number_inpatient  \
# 0                1                  0                 0                 0
# 1               18                  0                 0                 0
# 2               13                  2                 0                 1
# 3               16                  0                 0                 0
# 4                8                  0                 0                 0
#
#    diag_1  diag_2 diag_3  number_diagnoses max_glu_serum A1Cresult metformin  \
# 0  250.83     NaN    NaN                 1           NaN       NaN        No
# 1     276  250.01    255                 9           NaN       NaN        No
# 2     648     250    V27                 6           NaN       NaN        No
# 3       8  250.43    403                 7           NaN       NaN        No
# 4     197     157    250                 5           NaN       NaN        No
#
#   repaglinide nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# 0          No          No             No          No            No        No
# 1          No          No             No          No            No        No
# 2          No          No             No          No            No    Steady
# 3          No          No             No          No            No        No
# 4          No          No             No          No            No    Steady
#
#   glyburide tolbutamide pioglitazone rosiglitazone acarbose miglitol  \
# 0        No          No           No            No       No       No
# 1        No          No           No            No       No       No
# 2        No          No           No            No       No       No
# 3        No          No           No            No       No       No
# 4        No          No           No            No       No       No
#
#   troglitazone tolazamide insulin glyburide-metformin glipizide-metformin  \
# 0           No         No      No                  No                  No
# 1           No         No      Up                  No                  No
# 2           No         No      No                  No                  No
# 3           No         No      Up                  No                  No
# 4           No         No  Steady                  No                  No
#
#   glimepiride-pioglitazone metformin-rosiglitazone metformin-pioglitazone  \
# 0                       No                      No                     No
# 1                       No                      No                     No
# 2                       No                      No                     No
# 3                       No                      No                     No
# 4                       No                      No                     No
#
#   change diabetesMed  readmitted
# 0     No          No           0
# 1     Ch         Yes           0
# 2     No         Yes           0
# 3     Ch         Yes           0
# 4     Ch         Yes           0

# %%
X = df.drop("readmitted", axis=1)

y = df["readmitted"]

print(X.shape)
print(y.shape)
# Out:
# (101766, 44)
# (101766,)

# %%
print(y.value_counts())

print((y.value_counts(normalize=True)*100).round(2))
# Out:
# readmitted
# 0    90409
# 1    11357
# Name: count, dtype: int64
# readmitted
# 0    88.84
# 1    11.16
# Name: proportion, dtype: float64

# %%
rf = RandomForestClassifier(
    random_state=42
)

# encode categorical features before fitting
X_encoded = pd.get_dummies(X, drop_first=True)
rf.fit(X_encoded, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
feature_importance = pd.DataFrame({
    "Feature": X_encoded.columns,
    "Importance": rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(20)
# Out:
#                         Feature  Importance
# 4            num_lab_procedures    0.047748
# 6               num_medications    0.044592
# 3              time_in_hospital    0.034883
# 9              number_inpatient    0.033429
# 1      discharge_disposition_id    0.024941
# 5                num_procedures    0.024664
# 10             number_diagnoses    0.023898
# 0             admission_type_id    0.017825
# 2           admission_source_id    0.015429
# 15                  gender_Male    0.014257
# 7             number_outpatient    0.012330
# 113   medical_specialty_Unknown    0.011166
# 8              number_emergency    0.011084
# 12               race_Caucasian    0.010439
# 23                  age_[70-80)    0.009918
# 41           payer_code_Unknown    0.009754
# 22                  age_[60-70)    0.009678
# 32                payer_code_MC    0.009598
# 2408             insulin_Steady    0.009163
# 2417                  change_No    0.009152

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

plt.barh(
    feature_importance["Feature"][:20],
    feature_importance["Importance"][:20]
)

plt.gca().invert_yaxis()

plt.title("Top 20 Important Features")

plt.show()

# %%
selector = SelectKBest(
    score_func=mutual_info_classif,
    k="all"
)

selector.fit(X_encoded, y)
# Out:
# SelectKBest(k='all',
#             score_func=<function mutual_info_classif at 0x0000014C89570C20>)

# %%
mi_scores = pd.DataFrame({
    "Feature": X_encoded.columns,
    "Score": selector.scores_
})

mi_scores = mi_scores.sort_values(
    by="Score",
    ascending=False
)

mi_scores.head(20)
# Out:
#                         Feature     Score
# 2372             repaglinide_No  0.025702
# 2378          chlorpropamide_No  0.023724
# 2395           rosiglitazone_No  0.023722
# 2381             glimepiride_No  0.022518
# 2398                acarbose_No  0.021855
# 2401                miglitol_No  0.018016
# 2410     glyburide-metformin_No  0.017609
# 2369               metformin_No  0.017004
# 12               race_Caucasian  0.016961
# 2418            diabetesMed_Yes  0.016944
# 2375             nateglinide_No  0.016733
# 2385               glipizide_No  0.015318
# 2388               glyburide_No  0.015086
# 2417                  change_No  0.013563
# 15                  gender_Male  0.012766
# 2392            pioglitazone_No  0.012694
# 113   medical_specialty_Unknown  0.012358
# 2407                 insulin_No  0.011933
# 9              number_inpatient  0.011692
# 1      discharge_disposition_id  0.008903
